# %%
# %run NA_tasks_generator.py -n 10 -seed 2
# Out:
# args.natask == 'objrel'
# objrel	האורחת שהתייר מחזיק דוחפת את המאמנת	feminine	singular	masculine	singular	feminine	singular	דוחפות	מחזיקות
# objrel	האמנית שהעובד מאשים מפחידה את האורח	feminine	singular	masculine	singular	masculine	singular	מפחידות	מאשימות
# objrel	האמנית שהרופאה מביישת מצילה את המדריך	feminine	singular	feminine	singular	masculine	singular	מצילות	מביישות
# objrel	הדוגמנית שהנשיאה מושכת מארחת את השחקנית	feminine	singular	feminine	singular	feminine	singular	מארחות	מושכות
# objrel	הדודה שהמנתחת מרגשת מקללת את המדריכה	feminine	singular	feminine	singular	feminine	singular	מקללות	מרגשות
# objrel	הטבח שהאמריקאי מפחיד מכיר את האורח	masculine	singular	masculine	singular	masculine	singular	מכירים	מפחידים
# objrel	הטבח שהמאמן מבייש מרגש את השכנה	masculine	singular	masculine	singular	feminine	singular	מרגשים	מביישים
# objrel	הטבח שהמחנכת מעירה מחבק את השחקנית	masculine	singular	feminine	singular	feminine	singular	מחבקים	מעירים
# ...
